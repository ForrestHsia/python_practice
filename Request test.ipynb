# %%
import requests

# %%
get_url = "https://httpbin.org/get"
post_url = "https://httpbin.org/post"
auth_url = "https://httpbin.org/basic-auth/123456/456789"
delete_url = "https://httpbin.org/delete"

# %%
pixnet_post_url = "https://www.pixnet.net/mainpage/api/comments"

# %%
pixnet_delete_data= {
    'comment_id': "9308057171013bd8c9-personal://members/9308057171013bd8c9/articles/510d4b4386748c405abfb41f0e3aa3ba702a4a1d-510d4b4386748c405abfb41f0e3aa3ba702a4a1d",
    "service": "personal-post"
}

# %%
pixnet_header = {
    'X-XSRF-TOKEN': '9RFVnQF2256ki+38UjI8kCrKfVyOZTrvM9DrE5EYzvU=',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36 Edg/93.0.961.38'
}

# %%
pixnet_post = requests.delete(pixnet_post_url, headers = pixnet_header, params=pixnet_delete_data)

# %%
print(pixnet_post.text)
# Out:
# {"error":true,"status":401,"message":"請先登入會員"}

# %%
params = {
    "a" : "1",
    "b" : 1,
    "c" : "2021/9/10"
}

# %%
data = {
    'name':'forresthsia',
    'pw':'test30678'
}

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36 Edg/93.0.961.38"
}

# %%
get_result = requests.get(get_url,params=params)

# %%
post_result = requests.post(post_url,params=params, json = data)

# %%
auth_result = requests.get(auth_url, auth=('123456','456789'))

# %%
delete_result = requests.delete(delete_url,headers = headers,data = pixnet_data, params = delete_params)

# %%
delete_params = {
   'comment_id': '9308057171013bd8c9-personal://members/9308057171013bd8c9/articles/6cdf7e1932416955e88aa3cc5a26b0c16774f122-6cdf7e1932416955e88aa3cc5a26b0c16774f122',
    "service": "personal-post"
}

# %%
print(delete_result.text)
# Out:
# {
#   "args": {
#     "comment_id": "9308057171013bd8c9-personal://members/9308057171013bd8c9/articles/6cdf7e1932416955e88aa3cc5a26b0c16774f122-6cdf7e1932416955e88aa3cc5a26b0c16774f122",
#     "service": "personal-post"
#   },
#   "data": "{\"content\":\"123\",\"source\":\"www\",\"pictures\":[]}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "46",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36 Edg/93.0.961.38",
#     "X-Amzn-Trace-Id": "Root=1-613b2792-37a6933311d3d79c14162742"
#   },
#   "json": {
#     "content": "123",
#     "pictures": [],
#     "source": "www"
#   },
#   "origin": "27.247.41.95",
# ...

# %%
with open("fb_image.jpg", mode='rb') as file:
    image = {'upload_image':file.read()}
    post_result = requests.post(post_url,params=params, data=image, headers = headers)
    print(post_result.text)
# Out:
# {
#   "args": {
#     "a": "1",
#     "b": "1",
#     "c": "2021/9/10"
#   },
#   "data": "",
#   "files": {},
#   "form": {
# ...

# %%
print(auth_result.status_code)
# Out:
# 200
